# %% [markdown]
# <a href="https://colab.research.google.com/github/buttaakhil/LogisticRegression-PolynomialNature/blob/main/LR_Polynomial_Nature.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('polynomial-binary-lr.csv')
print(dataset.head(3))
# Out:
#          x1        x2  label
# 0 -4.765886  3.454060      1
# 1 -5.060424  5.933628      0
# 2  8.125092 -4.990642      1

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x="x1",y="x2",data=dataset,hue="label")
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["label"]

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf=PolynomialFeatures(degree=2)
pf.fit(x)
x=pd.DataFrame(pf.transform(x))

print(x.shape)
print(x.head(3))
# Out:
# (1000, 6)
#      0         1         2          3          4          5
# 0  1.0 -4.765886  3.454060  22.713672 -16.461657  11.930530
# 1  1.0 -5.060424  5.933628  25.607891 -30.026673  35.207941
# 2  1.0  8.125092 -4.990642  66.017114 -40.549424  24.906508

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
print(lr.score(x_test,y_test)*100)
# Out:
# 97.5
